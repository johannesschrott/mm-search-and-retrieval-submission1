# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from matplotlib.colors import LogNorm, Normalize
from matplotlib.ticker import MaxNLocator
import math

# %%
#data = pd.read_csv("data/id_lyrics_tf-idf_mmsr.tsv", sep="\t", index_col=0)
#data2 = pd.read_csv("data/id_blf_spectral_mmsr.tsv", sep="\t", index_col=0)

# %%
#data.isnull().values.any()

# %%
#data

# %%
#data.columns

# %%
#data = pd.DataFrame(columns=["id", ("banana", "tupsi"), ("hatschi", "patschi")])

# %%
#data

# %%
#data["id"]=[("banana", "tupsi"), ("hatschi", "patschi")]

# %%
#data.set_index("id", inplace=True)
#data

# %%
#corr = pd.concat([data, data2], axis=1)

# %%
#corr.corr()

# %%
#sn.heatmap(corr, annot=True)
#plt.matshow(data2.corr())
#plt.savefig("juhu.png", dpi=1200)
#plt.plot()
#plt.show()

# %%
data3 = pd.read_csv("correlation_matrix_1.csv", index_col=0)

# %%
sn.set(rc={'figure.figsize':(11.7*6,8.27*6)})
sn.diverging_palette(145, 300, s=60, as_cmap=True)
sn.color_palette("coolwarm", as_cmap=True)
#log_norm = LogNorm(vmin=data3.min().min(), vmax=data3.max().max())
sn.heatmap(data3, annot=True, norm = LogNorm())
plt.savefig("corr.pdf")
plt.show()
