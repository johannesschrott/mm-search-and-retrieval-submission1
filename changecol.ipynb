# %%
import pandas as pd

# %%
data = pd.read_csv("data/Pre_PCA_INCP_BERT_VDS_SCALED.csv", sep="\t", index_col=0)
data.head(10)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_48984\4010191647.py:1: DtypeWarning: Columns (1208) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data/Pre_PCA_INCP_BERT_VDS_SCALED.csv", sep="\t", index_col=0)
#           0         1         2         3         4         5         6  \
# 0 -1.727006  0.642637 -2.074936  1.354659 -0.099623  0.034994  1.567480
# 1 -1.716913  0.304076  1.332073 -0.445578  1.928106  2.059436  2.029958
# 2 -1.706820 -0.372412  0.246590 -0.130267 -1.772348 -1.837297  0.311604
# 3 -1.696726  0.848306  0.782374  0.645758 -0.085758 -0.348675  0.839483
# 4 -1.686633 -1.174407  0.281873  1.175072 -0.559486  0.143623 -1.057729
# 5 -1.676539 -0.320767  1.421913  0.791959 -0.421563  1.002017  1.427514
# 6 -1.666446 -0.501629 -1.456196 -0.299741  0.266801  0.412485  1.462341
# 7 -1.656353 -0.089943 -1.043884 -0.724419 -1.384847 -0.161381  0.440481
# ...

# %%
first_column = data.pop('id')
data.insert(0, 'id', first_column)

# %%
data.head()
# Out:
#                  id         0         1         2         3         4  \
# 0  0009fFIM1eYThaPg -1.727006  0.642637 -2.074936  1.354659 -0.099623
# 1  0010xmHR6UICBOYT -1.716913  0.304076  1.332073 -0.445578  1.928106
# 2  002Jyd0vN4HyCpqL -1.706820 -0.372412  0.246590 -0.130267 -1.772348
# 3  006TYKNjNxWjfKjy -1.696726  0.848306  0.782374  0.645758 -0.085758
# 4  007LIJOPQ4Sb98qV -1.686633 -1.174407  0.281873  1.175072 -0.559486
#
#           5         6         7         8  ...      1197      1198      1199  \
# 0  0.034994  1.567480  0.164173  0.988047  ...  0.024870  0.473042  1.771906
# 1  2.059436  2.029958 -1.676468 -0.297977  ... -1.206380  1.923245  1.254361
# 2 -1.837297  0.311604 -0.381610  0.067378  ...  0.654591  0.293124  0.934103
# 3 -0.348675  0.839483 -0.615816 -2.172079  ... -1.521847 -0.937321 -1.040893
# 4  0.143623 -1.057729 -0.224087  0.718027  ...  0.312359 -0.026507  0.573997
#
#        1200      1201      1202      1203      1204      1205      1206
# ...

# %%
data.set_index("id", inplace=True)

# %%
data.head()
# Out:
#                          0         1         2         3         4         5  \
# id
# 0009fFIM1eYThaPg -1.727006  0.642637 -2.074936  1.354659 -0.099623  0.034994
# 0010xmHR6UICBOYT -1.716913  0.304076  1.332073 -0.445578  1.928106  2.059436
# 002Jyd0vN4HyCpqL -1.706820 -0.372412  0.246590 -0.130267 -1.772348 -1.837297
# 006TYKNjNxWjfKjy -1.696726  0.848306  0.782374  0.645758 -0.085758 -0.348675
# 007LIJOPQ4Sb98qV -1.686633 -1.174407  0.281873  1.175072 -0.559486  0.143623
#
#                          6         7         8         9  ...      1197  \
# id                                                        ...
# 0009fFIM1eYThaPg  1.567480  0.164173  0.988047  1.015624  ...  0.024870
# 0010xmHR6UICBOYT  2.029958 -1.676468 -0.297977 -0.164640  ... -1.206380
# 002Jyd0vN4HyCpqL  0.311604 -0.381610  0.067378  0.316854  ...  0.654591
# 006TYKNjNxWjfKjy  0.839483 -0.615816 -2.172079  3.939274  ... -1.521847
# 007LIJOPQ4Sb98qV -1.057729 -0.224087  0.718027 -0.480861  ...  0.312359
#
# ...

# %%
data.to_csv("data/Pre_PCA_INCP_BERT_VDS_SCALED.tsv", sep="\t")

# %%
data.isna()
# Out:
#                       0      1      2      3      4      5      6      7  \
# id
# 0009fFIM1eYThaPg  False  False  False  False  False  False  False  False
# 0010xmHR6UICBOYT  False  False  False  False  False  False  False  False
# 002Jyd0vN4HyCpqL  False  False  False  False  False  False  False  False
# 006TYKNjNxWjfKjy  False  False  False  False  False  False  False  False
# 007LIJOPQ4Sb98qV  False  False  False  False  False  False  False  False
# ...                 ...    ...    ...    ...    ...    ...    ...    ...
# NaN               False  False  False  False  False  False  False  False
# NaN               False  False  False  False  False  False  False  False
# NaN               False  False  False  False  False  False  False  False
# NaN               False  False  False  False  False  False  False  False
# NaN               False  False  False  False  False  False  False  False
#
#                       8      9  ...   1197   1198   1199   1200   1201   1202  \
# ...

# %%
dataisnan = data.isna().any
dataisnan
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of                       0      1      2      3      4      5      6      7  \
# id
# 0009fFIM1eYThaPg  False  False  False  False  False  False  False  False
# 0010xmHR6UICBOYT  False  False  False  False  False  False  False  False
# 002Jyd0vN4HyCpqL  False  False  False  False  False  False  False  False
# 006TYKNjNxWjfKjy  False  False  False  False  False  False  False  False
# 007LIJOPQ4Sb98qV  False  False  False  False  False  False  False  False
# ...                 ...    ...    ...    ...    ...    ...    ...    ...
# NaN               False  False  False  False  False  False  False  False
# NaN               False  False  False  False  False  False  False  False
# NaN               False  False  False  False  False  False  False  False
# NaN               False  False  False  False  False  False  False  False
# NaN               False  False  False  False  False  False  False  False
#
# ...

# %%
data.dropna(inplace=True)

# %%
data.to_csv("data/Pre_PCA_INCP_BERT_VDS_SCALED.tsv", sep="\t")

# %%
data
# Out:
#                          0         1         2         3         4         5  \
# id
# 0009fFIM1eYThaPg -1.727006  0.642637 -2.074936  1.354659 -0.099623  0.034994
# 0010xmHR6UICBOYT -1.716913  0.304076  1.332073 -0.445578  1.928106  2.059436
# 002Jyd0vN4HyCpqL -1.706820 -0.372412  0.246590 -0.130267 -1.772348 -1.837297
# 006TYKNjNxWjfKjy -1.696726  0.848306  0.782374  0.645758 -0.085758 -0.348675
# 007LIJOPQ4Sb98qV -1.686633 -1.174407  0.281873  1.175072 -0.559486  0.143623
# ...                    ...       ...       ...       ...       ...       ...
# NaN               0.796340 -0.737973  0.204018  0.615315 -0.044075 -1.229089
# NaN               0.806434  0.633272 -0.340443  0.586016  0.617835 -0.893537
# NaN               0.816527 -0.731533 -0.799655 -0.271137  0.218629  1.314864
# NaN               0.826621  0.384973  0.255121  0.883475 -1.104340  0.655989
# NaN               0.836714 -0.428311 -0.550599  1.568908 -0.445983 -0.681166
#
# ...
